# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt



cc_num =pd.read_csv('df-def.csv')

cc_num = cc_num.drop('Unnamed: 0', axis = 1)

# %%
cc_num
# Out:
#         qb2  qb5  qb4_3  qb4_5  qb7  qb8  qb9                 d1    d10  d11  \
# 0       4.0    0      2      2    2    2    2             centro    Man   20
# 1       5.0    0      2      2    2    2    2             centro    Man   55
# 2       6.0    0      2      2    2    1    1          centro-sx    Man   80
# 3       6.0    1      2      2    2    2    2             centro    Man   40
# 4       5.0    1      3      3    2    3    2             centro    Man   55
# ...     ...  ...    ...    ...  ...  ...  ...                ...    ...  ...
# 21973  10.0    0      2      2    2    2    2  non-posizionabile  Woman   40
# 21974  10.0    0      2      2    2    1    2  non-posizionabile  Woman   46
# 21975  10.0    0      2      1    2    2    1             centro  Woman   40
# 21976  10.0    0      2      1    1    1    1  non-posizionabile  Woman   36
# 21977  10.0    0      1      1    2    1    1  non-posizionabile    Man   35
#
#                               d25               d8  \
# 0                      Large town    20+ years old
# 1                      Large town       Refusal/dk
# 2                      Large town       Refusal/dk
# 3                      Large town       Refusal/dk
# 4                      Large town       Refusal/dk
# ...                           ...              ...
# 21973  Small or middle sized town  16-19 years old
# 21974       Rural area or village  16-19 years old
# 21975       Rural area or village  16-19 years old
# 21976       Rural area or village    20+ years old
# 21977       Rural area or village  16-19 years old
#
#                                      d63                  d7  country  cca  \
# 0            The middle class of society              single  Belgium    1
# 1            The middle class of society  con patner e figli  Belgium    1
# 2      The lower middle class of society              single  Belgium    2
# 3      The lower middle class of society  con patner e figli  Belgium    1
# 4            The middle class of society  con patner e figli  Belgium    2
# ...                                  ...                 ...      ...  ...
# 21973        The middle class of society  con patner e figli  Croatia    1
# 21974        The middle class of society          con patner  Croatia    2
# 21975        The middle class of society              single  Croatia    3
# 21976        The middle class of society          con patner  Croatia    5
# 21977       The working class of society          con patner  Croatia    3
#
#        cluster                            dip2x2  \
# 0            2  non fa niente e non si preoccupa
# 1            2  non fa niente e non si preoccupa
# 2            1      non fa niente e si preoccupa
# 3            2        fa qualcosa e si preoccupa
# 4            4    fa qualcosa e non si preoccupa
# ...        ...                               ...
# 21973        2      non fa niente e si preoccupa
# 21974        2      non fa niente e si preoccupa
# 21975        5      non fa niente e si preoccupa
# 21976        3      non fa niente e si preoccupa
# 21977        3      non fa niente e si preoccupa
#
#                                         dip3x2
# 0      non fa niente e si preoccupa abbastanza
# 1      non fa niente e si preoccupa abbastanza
# 2      non fa niente e si preoccupa abbastanza
# 3        fa qualcosa e si preoccupa abbastanza
# 4        fa qualcosa e si preoccupa abbastanza
# ...                                        ...
# 21973       non fa niente e si preoccupa molto
# 21974       non fa niente e si preoccupa molto
# 21975       non fa niente e si preoccupa molto
# 21976       non fa niente e si preoccupa molto
# 21977       non fa niente e si preoccupa molto
#
# [21978 rows x 19 columns]

# %%
c = cc_num.groupby('country').mean().reset_index()

print("average of chimate change risk perception is", c.qb2.mean())
# Out:
# average of chimate change risk perception is 7.9556402957609516

# %%
con = cc_num.groupby('country').count().reset_index()
con
# Out:
#            country   qb2   qb5  qb4_3  qb4_5   qb7   qb8   qb9    d1   d10  \
t.ylabel("Average attitude towards the problem of climate change")
plt.xticks(rotation=45, ha='right')



#####horizontal line
plt.axhline(y=c.qb2.mean(), color='r', linestyle='dotted')


# Display the graph on the screen
plt.show()

# %%
plt.figure(figsize=(15,8))

country = c.country
unit = c.qb4_3
 
# Plot the bar graph
plot = plt.bar(country, unit)


# Add labels and title
plt.title("To what extent do you agree or disagree with each of the following statements? (scale 1-4)  \n Taking action on climate change will lead to innovation that will make EU companies more competitive ")
plt.xlabel("Country")
plt.ylabel("Average attitude towards the problem of climate change")
plt.xticks(rotation=45, ha='right')



#####horizontal line
plt.axhline(y=c.qb4_3.mean(), color='r', linestyle='dotted')


# Display the graph on the screen
plt.show()

# %%
plt.figure(figsize=(15,8))

country = c.country
unit = c.qb4_5
 
# Plot the bar graph
plot = plt.bar(country, unit)


# Add labels and title
plt.title("To what extent do you agree or disagree with each of the following statements? (scale 1-4)  \n Adapting to the adverse impacts of climate change can have positive outcomes for citizens in the EU")
plt.xlabel("Country")
plt.ylabel("Average attitude towards the problem of climate change")
plt.xticks(rotation=45, ha='right')



#####horizontal line
plt.axhline(y=c.qb4_5.mean(), color='r', linestyle='dotted')


# Display the graph on the screen
plt.show()

# %%
plt.figure(figsize=(15,8))

country = c.country
unit = c.qb7
 
# Plot the bar graph
plot = plt.bar(country, unit)


# Add labels and title
plt.title("How important do you think it is that the (NATIONALITY) government sets ambitious targets to increase the amount of renewable energy used, \n such as wind or solar power, by 2030? (scale 1-4)")
plt.xlabel("Country")
plt.ylabel("Average attitude towards the question")
plt.xticks(rotation=45, ha='right')



#####horizontal line
plt.axhline(y=c.qb7.mean(), color='r', linestyle='dotted')


# Display the graph on the screen
plt.show()

# %%
plt.figure(figsize=(15,8))

country = c.country
unit = c.qb8
 
# Plot the bar graph
plot = plt.bar(country, unit)


# Add labels and title
plt.title("How important do you think it is that the (NATIONALITY) government provides support for improving energy efficiency by 2030 \n (e.g. by encouraging people to insulate their home or buy electric cars)? (scale 1-4)")
plt.xlabel("Country")
plt.ylabel("Average attitude towards the question")
plt.xticks(rotation=45, ha='right')

#####horizontal line
plt.axhline(y=c.qb8.mean(), color='r', linestyle='dotted')


# Display the graph on the screen
plt.show()

# %%
plt.figure(figsize=(15,8))

country = c.country
unit = c.qb9
 
# Plot the bar graph
plot = plt.bar(country, unit)


# Add labels and title
plt.title("To what extent do you agree or disagree with the following statement: \n We should reduce greenhouse gas emissions to a minimum while offsetting the remaining emissions, \n for instance by increasing forested areas, to make the EU economy climate neutral by 2050.(scale 1-4)")
plt.xlabel("Country")
plt.ylabel("Average attitude towards the question")
plt.xticks(rotation=45, ha='right')

#####horizontal line
plt.axhline(y=c.qb9.mean(), color='r', linestyle='dotted')


# Display the graph on the screen
plt.show()

# %%
print(c.qb4_5.mean()) #più alta
print(c.qb7.mean())
print(c.qb8.mean())
print(c.qb9.mean())
# Out:
# 1.9139815243509068
# 1.5157515264070542
# 1.5560230984599275
# 1.4961609393826938

# %%
c1  = cc_num.groupby([ 'd1']).count().reset_index()
c1
# Out:
#                   d1   qb2   qb5  qb4_3  qb4_5   qb7   qb8   qb9   d10   d11  \
# 0             centro  7968  7968   7968   7968  7968  7968  7968  7968  7968
# 1          centro-dx  3470  3470   3470   3470  3470  3470  3470  3470  3470
# 2          centro-sx  3856  3856   3856   3856  3856  3856  3856  3856  3856
# 3                 dx  1603  1603   1603   1603  1603  1603  1603  1603  1603
# 4  non-posizionabile  3228  3228   3228   3228  3228  3228  3228  3228  3228
# 5                 sx  1853  1853   1853   1853  1853  1853  1853  1853  1853
#
#     d25    d8   d63    d7  country   cca  cluster  dip2x2  dip3x2
# 0  7968  7968  7968  7968     7968  7968     7968    7968    7968
# 1  3470  3470  3470  3470     3470  3470     3470    3470    3470
# 2  3856  3856  3856  3856     3856  3856     3856    3856    3856
# 3  1603  1603  1603  1603     1603  1603     1603    1603    1603
# 4  3228  3228  3228  3228     3228  3228     3228    3228    3228
# 5  1853  1853  1853  1853     1853  1853     1853    1853    1853

# %%
plt.figure(figsize=(15,8))

pol = ['sx', 'cnetro-sx', 'centro', 'centro-dx', 'dx', 'non-posizionabile']
unit = [1853,3856,7968,3470,  1603,3228 ]
 
# Plot the bar graph
plot = plt.bar(pol, unit)


# Add labels and title
plt.title("political orientation")
#plt.xlabel("Country")
plt.ylabel("count")
plt.xticks(rotation=45, ha='right')


# Display the graph on the screen
plt.show()

# %%
c1  = cc_num.groupby([ 'country','d1'])['country'].count().unstack()
c1.head()
# Out:
# d1        centro  centro-dx  centro-sx  dx  non-posizionabile   sx
# country
# Austria      236        136        211  38                109  100
# Belgium      449        205        174  35                 41   66
# Bulgaria     174        125         82  87                 78   80
# Croatia      348        131        168  92                 89   76
# Cyprus       111         34         28  43                170   25

# %%
c1.plot(kind='bar', rot=0, stacked=True)

# Add labels and title
plt.title("political orientation")
#plt.xlabel("Country")
plt.ylabel("count")

plt.xticks(rotation=45, ha='right')
plt.xlabel('')  # remove unnecessary 'state' label
plt.ylabel('Number of Complaints')

plt.tight_layout()


plt.legend(loc='upper right')
   
plt.gcf().set_size_inches(20, 10)

    
plt.show()

# %%
c = cc_num.groupby(['country', 'qb4_3']).agg({'qb4_3': 'sum'})

# Change: groupby state_office and divide by sum
c = c.groupby(level=0).apply(lambda x:
                                                 100 * x / float(x.sum()))

c
# Out:
#                           qb4_3
# country        qb4_3
# Austria        1      20.454545
#                2      45.844156
#                3      25.129870
#                4       8.571429
# Belgium        1      17.463849
# ...                         ...
# Sweden         4       3.646564
# United Kingdom 1      26.175439
#                2      56.421053
#                3      12.631579
#                4       4.771930
#
# [112 rows x 1 columns]

# %%
freq_df =  cc_num.groupby(['country'])['qb2'].value_counts().unstack()
#freq_df = freq_df[['low', 'medium', 'high']]
pct_df = freq_df.divide(freq_df.sum(axis=1), axis=0)
pct_df.plot(kind="bar", stacked=True)

plt.legend(loc='upper right')
   
plt.gcf().set_size_inches(20, 10)


# Add labels and title
plt.title("Climate Change Risk Perception per Country")
plt.xlabel("Country")
plt.ylabel("Percentage")
plt.xticks(rotation=45, ha='right')

plt.savefig('Climate Change Risk Perception per Country.png', bbox_inches='tight')
# Display the graph on the screen
plt.show()

# %%
freq_df =  cc_num.groupby(['country'])['qb4_3'].value_counts().unstack()
pct_df = freq_df.divide(freq_df.sum(axis=1), axis=0)
ax = pct_df.plot(kind="bar", stacked=True)

plt.legend(loc='upper right')
   
plt.gcf().set_size_inches(20, 10)


# Add labels and title
plt.title("To what extent do you agree or disagree with each of the following statements? (scale 1-4)  \n Taking action on climate change will lead to innovation that will make EU companies more competitive ")
plt.xlabel("Country")
#plt.ylabel("Average attitude towards the problem of climate change")
plt.xticks(rotation=45, ha='right')
ax.legend(["1 - Totally agree", "2", "3", "4 - Totally disagree "], bbox_to_anchor=(1,0), loc="lower right");


# Display the graph on the screen
plt.show()

# %%
freq_df =  cc_num.groupby(['country'])['qb4_5'].value_counts().unstack()
pct_df = freq_df.divide(freq_df.sum(axis=1), axis=0)
ax = pct_df.plot(kind="bar", stacked=True)

plt.legend(loc='upper right')
   
plt.gcf().set_size_inches(20, 10)


# Add labels and title
plt.title("To what extent do you agree or disagree with each of the following statements? (scale 1-4)  \n Adapting to the adverse impacts of climate change can have positive outcomes for citizens in the EU")
plt.xlabel("Country")
#plt.ylabel("Average attitude towards the problem of climate change")
plt.xticks(rotation=45, ha='right')

ax.legend(["1 - Totally agree", "2", "3", "4 - Totally disagree "], bbox_to_anchor=(1,0), loc="lower right");

# Display the graph on the screen
plt.show()

# %%
freq_df =  cc_num.groupby(['country'])['qb7'].value_counts().unstack()
pct_df = freq_df.divide(freq_df.sum(axis=1), axis=0)
ax = pct_df.plot(kind="bar", stacked=True)

plt.legend(loc='upper right')
   
plt.gcf().set_size_inches(20, 10)


# Add labels and title
plt.title("How important do you think it is that the (NATIONALITY) government sets ambitious targets to increase the amount of renewable energy used, \n such as wind or solar power, by 2030? (scale 1-4)")
plt.xlabel("Country")
#plt.ylabel("Average attitude towards the problem of climate change")
plt.xticks(rotation=45, ha='right')

ax.legend(["1 - Totally agree", "2", "3", "4 - Totally disagree "], bbox_to_anchor=(1,0), loc="lower right");

# Display the graph on the screen
plt.show()

# %%
freq_df =  cc_num.groupby(['country'])['qb8'].value_counts().unstack()
pct_df = freq_df.divide(freq_df.sum(axis=1), axis=0)
ax = pct_df.plot(kind="bar", stacked=True)

plt.legend(loc='upper right')
   
plt.gcf().set_size_inches(20, 10)


# Add labels and title
plt.title("How important do you think it is that the (NATIONALITY) government provides support for improving energy efficiency by 2030 \n (e.g. by encouraging people to insulate their home or buy electric cars)? (scale 1-4)")
plt.xlabel("Country")
#plt.ylabel("Average attitude towards the problem of climate change")
plt.xticks(rotation=45, ha='right')
ax.legend(["1 - Totally agree", "2", "3", "4 - Totally disagree "], bbox_to_anchor=(1,0), loc="lower right");


# Display the graph on the screen
plt.show()

# %%
freq_df =  cc_num.groupby(['country'])['qb9'].value_counts().unstack()
pct_df = freq_df.divide(freq_df.sum(axis=1), axis=0)
ax = pct_df.plot(kind="bar", stacked=True)

   
plt.gcf().set_size_inches(20, 10)


# Add labels and title
plt.title("To what extent do you agree or disagree with the following statement: \n We should reduce greenhouse gas emissions to a minimum while offsetting the remaining emissions, \n for instance by increasing forested areas, to make the EU economy climate neutral by 2050.(scale 1-4)")
plt.xlabel("Country")
#plt.ylabel("Average attitude towards the problem of climate change")
plt.xticks(rotation=45, ha='right')

ax.legend(["1 - Totally agree", "2", "3", "4 - Totally disagree "], bbox_to_anchor=(1,0), loc="lower right");

# Display the graph on the screen
plt.show()

# %%
freq_df =  cc_num.groupby(['country'])['qb5'].value_counts().unstack()
pct_df = freq_df.divide(freq_df.sum(axis=1), axis=0)
ax = pct_df.plot(kind="bar", stacked=True)

   
plt.gcf().set_size_inches(20, 10)


# Add labels and title
plt.title("Have you personally taken any action to fight climate change over the past six months?")
plt.xlabel("Country")
#plt.ylabel("Average attitude towards the problem of climate change")
plt.xticks(rotation=45, ha='right')

ax.legend(["no", "yes",], bbox_to_anchor=(1,0), loc="lower right");

# Display the graph on the screen
plt.show()

# %%
freq_df =  cc_num.groupby(['country'])['dip2x2'].value_counts().unstack()
pct_df = freq_df.divide(freq_df.sum(axis=1), axis=0)
ax = pct_df.plot(kind="bar", stacked=True)

   
plt.gcf().set_size_inches(20, 10)


# Add labels and title
plt.title("Action and percetion")
plt.xlabel("Country")
#plt.ylabel("Average attitude towards the problem of climate change")
plt.xticks(rotation=45, ha='right')

ax.legend(["fa qualcosa e non si preoccupa	", "fa qualcosa e si preoccupa", "non fa niente e non si preoccupa", "non fa niente e si preoccupa"], bbox_to_anchor=(1,0), loc="lower right");

# Display the graph on the screen
plt.show()
# Out:
# C:\Users\giusp\AppData\Roaming\Python\Python37\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\giusp\AppData\Roaming\Python\Python37\site-packages\matplotlib\backends\backend_agg.py:183: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
freq_df =  cc_num.groupby(['d1'])['qb5'].value_counts().unstack()
pct_df = freq_df.divide(freq_df.sum(axis=1), axis=0)
ax = pct_df.plot(kind="bar", stacked=True)

   
plt.gcf().set_size_inches(20, 10)


# Add labels and title
plt.title("Action and percetion")
plt.xlabel("Country")
#plt.ylabel("Average attitude towards the problem of climate change")
plt.xticks(rotation=45, ha='right')

ax.legend(["no", "yes"], bbox_to_anchor=(1,0), loc="lower right");

# Display the graph on the screen
plt.show()

# %%
freq_df
# Out:
# dip2x2          fa qualcosa e non si preoccupa  fa qualcosa e si preoccupa  \
# country
# Austria                                     91                         495
# Belgium                                     72                         544
# Bulgaria                                    14                         261
# Croatia                                     63                         440
# Cyprus                                      25                         242
# Czech Republic                              36                         291
# Denmark                                     66                         583
# Estonia                                     57                         219
# Finland                                     95                         569
# France                                      30                         514
# Germany                                     84                         794
# Greece                                      10                         497
# Hungary                                     27                         588
# Ireland                                     50                         570
# Italy                                       24                         484
# Latvia                                      52                         265
# Lithuania                                   60                         336
# Luxembourg                                  27                         300
# Malta                                        6                         354
# Netherlands                                 73                         520
# Poland                                      38                         297
# Portugal                                    36                         653
# Romania                                     23                         267
# Slovakia                                    57                         518
# Slovenia                                    78                         641
# Spain                                       27                         655
# Sweden                                      67                         641
# United Kingdom                              51                         450
#
# dip2x2          non fa niente e non si preoccupa  non fa niente e si preoccupa
# country
# Austria                                       90                           154
# Belgium                                       82                           272
# Bulgaria                                      32                           319
# Croatia                                       97                           304
# Cyprus                                        13                           131
# Czech Republic                               109                           293
# Denmark                                       34                           156
# Estonia                                       84                           160
# Finland                                       42                           101
# France                                        57                           196
# Germany                                       69                           253
# Greece                                        22                           325
# Hungary                                       45                           240
# Ireland                                       52                           256
# Italy                                         50                           347
# Latvia                                       122                           248
# Lithuania                                     73                           235
# Luxembourg                                    17                            55
# Malta                                          1                            36
# Netherlands                                   77                           213
# Poland                                        53                           322
# Portugal                                      12                           162
# Romania                                      128                           451
# Slovakia                                      39                           196
# Slovenia                                      32                           123
# Spain                                          8                           130
# Sweden                                        44                           138
# United Kingdom                                83                           268

# %%
#map 


c = cc_num.groupby('country').mean().reset_index()

# %%
c#function to convert to alpah2 country codes and continents
from pycountry_convert import country_alpha2_to_continent_code, country_name_to_country_alpha2
def get_continent(col):
    try:
        cn_a2_code =  country_name_to_country_alpha2(col)
    except:
        cn_a2_code = 'Unknown' 
    try:
        cn_continent = country_alpha2_to_continent_code(cn_a2_code)
    except:
        cn_continent = 'Unknown' 
    return (cn_a2_code, cn_continent)

# %%
get_continent(c.country)
# Out:
# ('Unknown', 'Unknown')

# %%
from geopy.geocoders import Nominatim
geolocator = Nominatim()

c['lat'] = np.nan
c['long'] = np.nan
for i in range(len(c)):
        # Geolocate the center of the country
    loc = geolocator.geocode(c.country[i])
        # And return latitude and longitude
    c['lat'][i] = float(loc.latitude)
    c['long'][i] = float(loc.longitude)
# Out:
# C:\Users\giusp\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: Using Nominatim with the default "geopy/1.20.0" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.
#
# C:\Users\giusp\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# C:\Users\giusp\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()

# %%
c
# Out:
#            country       qb2       qb5     qb4_3     qb4_5       qb7  \
# 0          Austria  7.445783  0.706024  1.855422  2.048193  1.607229
# 1          Belgium  7.523711  0.635052  1.853608  1.936082  1.556701
# 2         Bulgaria  8.346645  0.439297  1.650160  1.934505  1.602236
# 3          Croatia  7.621681  0.556416  1.763274  1.868363  1.633850
# 4           Cyprus  8.445255  0.649635  1.462287  1.761557  1.124088
# 5   Czech Republic  7.525377  0.448560  2.098765  2.299040  1.788752
# 6          Denmark  8.203814  0.773540  1.690107  1.600715  1.293206
# 7          Estonia  7.036538  0.530769  2.026923  2.611538  1.607692
# 8          Finland  7.508055  0.822800  1.767038  2.231722  1.655514
# 9           France  8.274780  0.682560  1.792974  2.076537  1.504391
# 10         Germany  8.167500  0.731667  1.838333  2.125000  1.600000
# 11          Greece  8.656909  0.593677  1.586651  1.911007  1.374707
# 12         Hungary  8.314444  0.683333  1.771111  1.796667  1.517778
# 13         Ireland  8.064655  0.668103  1.550647  1.505388  1.368534
AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
# definition of the boundaries in the map: crime total in two years
import json
communities_geo = r'european-union-countries.geojson'
# open the json file - json.load() methods returns a python dictionary
with open(communities_geo) as communities_file:
    communities_json = json.load(communities_file)
    
# we loop through the dictionary to obtain the name of the communities in the json file
denominations_json = []
for index in range(len(communities_json['features'])):
    denominations_json.append(communities_json['features'][index]['properties']['name'])
    
denominations_json
# Out:
# ['Slovenia',
#  'Belgium',
#  'Ireland',
#  'Romania',
#  'Latvia',
#  'Poland',
#  'Greece',
#  'Slovakia',
#  'Hungary',
#  'Denmark',
#  'Finland',
#  'United Kingdom',
#  'Lithuania',
#  'Croatia',
#  'Spain',
#  'Austria',
#  'Czech Rep.',
#  'Netherlands',
#  'Italy',
#  'Estonia',
#  'Sweden',
#  'Portugal',
#  'Bulgaria',
#  'Malta',
#  'Germany',
#  'Luxembourg',
#  'Cyprus',
#  'France']

# %%
###############################################################################
#                         14. Make Choropleth Crime Map                      #
###############################################################################
# Create base map

import folium
# Get Lat and Long
lats = c["lat"].values
lngs = c["long"].values

communities_map = folium.Map(location=[np.mean(lats), np.mean(lngs)], 
               tiles = 'cartodbpositron', zoom_start = 5) #oppure metti 'Stamen Toner' su tiles


communities_map.choropleth(geo_data = communities_geo, 
            data = c,
            columns = ['country', 'qb2'],
            name='choropleth',
              key_on = 'feature.properties.name',
              fill_color = 'YlOrRd', 
              fill_opacity = 0.7, 
              line_opacity = 0.2,
              legend_name = 'Average attitude towards climate change risk perception',
               highlight = True)
#display(communities_map)

# Add a control button
#folium.map.LayerControl('topleft', collapsed= False).add_to(m)
communities_map.save('Simple Map_prova.html')

# %% [markdown]
# ### categorical variables
#
#
# devo ribeccare la variabile qb1a

# %%
cc_num2 =pd.read_csv('qb1a.csv')
cc_num['qb1a'] = cc_num2['qb1a']

# %%
country = cc_num.groupby('country').count().reset_index()
country = country.rename(columns={'qb1a': 'N'})
country.head()
# Out:
#     country  qb2  qb5  qb4_3  qb4_5  qb7  qb8  qb9   d1  d10  d11  d25   d8  \
# 0   Austria  830  830    830    830  830  830  830  830  830  830  830  830
# 1   Belgium  970  970    970    970  970  970  970  970  970  970  970  970
# 2  Bulgaria  626  626    626    626  626  626  626  626  626  626  626  626
# 3   Croatia  904  904    904    904  904  904  904  904  904  904  904  904
# 4    Cyprus  411  411    411    411  411  411  411  411  411  411  411  411
#
#    d63   d7  cca  cluster  dip2x2  dip3x2    N
# 0  830  830  830      830     830     830  830
# 1  970  970  970      970     970     970  970
# 2  626  626  626      626     626     626  626
# 3  904  904  904      904     904     904  904
# 4  411  411  411      411     411     411  411

# %%
cc = cc_num.groupby(['country','qb1a']).count().reset_index()
cc
# Out:
#             country                                        qb1a  qb2  qb5  \
# 0           Austria                             Armed conflicts   76   76
# 1           Austria                              Climate change  229  229
# 2           Austria                     International terrorism  103  103
# 3           Austria                         Other (SPONTANEOUS)    3    3
# 4           Austria  Poverty, hunger and lack of drinking water  177  177
# ..              ...                                         ...  ...  ...
# 281  United Kingdom            Proliferation of nuclear weapons   28   28
# 282  United Kingdom               Spread of infectious diseases    8    8
# 283  United Kingdom                      The economic situation   58   58
# 284  United Kingdom            The increasing global population   89   89
# 285  United Kingdom                                          dk   10   10
#
#      qb4_3  qb4_5  qb7  qb8  qb9   d1  d10  d11  d25   d8  d63   d7  cca  \
# 0       76     76   76   76   76   76   76   76   76   76   76   76   76
# 1      229    229  229  229  229  229  229  229  229  229  229  229  229
# 2      103    103  103  103  103  103  103  103  103  103  103  103  103
# 3        3      3    3    3    3    3    3    3    3    3    3    3    3
# 4      177    177  177  177  177  177  177  177  177  177  177  177  177
# ..     ...    ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 281     28     28   28   28   28   28   28   28   28   28   28   28   28
# 282      8      8    8    8    8    8    8    8    8    8    8    8    8
# 283     58     58   58   58   58   58   58   58   58   58   58   58   58
# 284     89     89   89   89   89   89   89   89   89   89   89   89   89
# 285     10     10   10   10   10   10   10   10   10   10   10   10   10
#
#      cluster  dip2x2  dip3x2
# 0         76      76      76
# 1        229     229     229
# 2        103     103     103
# 3          3       3       3
# 4        177     177     177
# ..       ...     ...     ...
# 281       28      28      28
# 282        8       8       8
# 283       58      58      58
# 284       89      89      89
# 285       10      10      10
#
# [286 rows x 20 columns]

# %%
cc = cc.loc[cc['qb1a'] == 'Climate change']
cc = cc[['country', 'd1']]
cc = cc.rename(columns={'d1': 'count_climatechange'})

cc
# Out:
#             country  count_climatechange
# 1           Austria                  229
# 11          Belgium                  218
# 20         Bulgaria                   71
# 31          Croatia                  104
# 42           Cyprus                   58
# 51   Czech Republic                   97
# 60          Denmark                  387
# 71          Estonia                   84
# 82          Finland                  243
# 91           France                  193
# 100         Germany                  357
# 110          Greece                  105
# 120         Hungary                  152
# 131         Ireland                  267
# 142           Italy                  162
# 152          Latvia                   85
# 163       Lithuania                  100
# 174      Luxembourg                   97
# 183           Malta                  128
# 193     Netherlands                  236
# 204          Poland                  119
# 214        Portugal                  168
# 225         Romania                  105
# 236        Slovakia                  100
# 245        Slovenia                  168
# 256           Spain                  161
# 266          Sweden                  437
# 276  United Kingdom                  249

# %%
result =pd.merge(cc, country, how='left', left_on='country', right_on='country')
result.head()
# Out:
#     country  count_climatechange  qb2  qb5  qb4_3  qb4_5  qb7  qb8  qb9   d1  \
# 0   Austria                  229  830  830    830    830  830  830  830  830
# 1   Belgium                  218  970  970    970    970  970  970  970  970
# 2  Bulgaria                   71  626  626    626    626  626  626  626  626
# 3   Croatia                  104  904  904    904    904  904  904  904  904
# 4    Cyprus                   58  411  411    411    411  411  411  411  411
#
#    ...  d11  d25   d8  d63   d7  cca  cluster  dip2x2  dip3x2    N
# 0  ...  830  830  830  830  830  830      830     830     830  830
# 1  ...  970  970  970  970  970  970      970     970     970  970
# 2  ...  626  626  626  626  626  626      626     626     626  626
# 3  ...  904  904  904  904  904  904      904     904     904  904
# 4  ...  411  411  411  411  411  411      411     411     411  411
#
# [5 rows x 21 columns]

# %%
result['percent'] = result['count_climatechange']/result['N']*100
result
# Out:
#            country  count_climatechange   qb2   qb5  qb4_3  qb4_5   qb7   qb8  \
# 7    520  16.153846
# 8    807  30.111524
# 9    797  24.215809
# 10  1200  29.750000
# 11   854  12.295082
# 12   900  16.888889
# 13   928  28.771552
# 14   905  17.900552
# 15   687  12.372635
# 16   704  14.204545
# 17   399  24.310777
# 18   397  32.241814
# 19   883  26.727067
# 20   710  16.760563
# 21   863  19.466976
# 22   869  12.082854
# 23   810  12.345679
# 24   874  19.221968
# 25   820  19.634146
# 26   890  49.101124
# 27   852  29.225352
#
# [28 rows x 22 columns]

# %%
plt.figure(figsize=(15,8))

country = result.country
unit = result.percent
 
# Plot the bar graph
plot = plt.bar(country, unit)


# Add labels and title
plt.title("The percentage of those who believe that the single most serious problem is climate change per country")
plt.xlabel("Country")
plt.ylabel("Percentage")
plt.xticks(rotation=45, ha='right')

#####horizontal line
plt.axhline(y=result.percent.mean(), color='r', linestyle='dotted')


plt.savefig('The percentage of those who believe that the single most serious problem is climate change per country.png', bbox_inches='tight')


# Display the graph on the screen
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fig, (ax1, ax2) = plt.subplots(ncols=2, sharey=True, figsize = (15,5))         
sns.countplot(x=cc_num['qb4_3'],hue=cc_num['cluster'],  ax=ax1)
sns.countplot(x=cc_num['qb4_3'],hue=cc_num['cca'],  ax=ax2)
ax1.legend(loc = 'upper right', title='cluster')

plt.suptitle('To what extent do you agree or disagree with each of the following statements? \n Taking action on climate change will lead to innovation that will make EU companies more competitive ') # can also get the figure from plt.gcf()
plt.savefig('qb4_3-count-cc.png')
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, sharey=True, figsize = (15,5))         
sns.countplot(x=cc_num['qb4_5'],hue=cc_num['cluster'],  ax=ax1)
sns.countplot(x=cc_num['qb4_5'],hue=cc_num['cca'],  ax=ax2)
ax1.legend(loc = 'upper right', title='cluster')
plt.suptitle('To what extent do you agree or disagree with each of the following statements? \n Adapting to the adverse impacts of climate change can have positive outcomes for citizens in the EU')
plt.savefig('qb4_5-count-cc.png')

plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, sharey=True, figsize = (15,5))         
sns.countplot(x=cc_num['qb7'],hue=cc_num['cluster'],  ax=ax1)
sns.countplot(x=cc_num['qb7'],hue=cc_num['cca'],  ax=ax2)
ax1.legend(loc = 'upper right', title='cluster')
plt.suptitle('How important do you think it is that the (NATIONALITY) government sets ambitious targets \n to increase the amount of renewable energy used, such as wind or solar power, by 2030? ')
plt.savefig('qb7-count-cc.png')

plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, sharey=True, figsize = (15,6))         
sns.countplot(x=cc_num['qb8'],hue=cc_num['cluster'],  ax=ax1)
sns.countplot(x=cc_num['qb8'],hue=cc_num['cca'],  ax=ax2)
ax1.legend(loc = 'upper right', title='cluster')
plt.suptitle('How important do you think it is that the (NATIONALITY) government provides support for improving energy efficiency by 2030 \n (e.g. by encouraging people to insulate their home or buy electric cars)?')
plt.savefig('qb8-count-cc.png')

plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, sharey=True, figsize = (15,7))         
sns.countplot(x=cc_num['qb9'],hue=cc_num['cluster'],  ax=ax1)
sns.countplot(x=cc_num['qb9'],hue=cc_num['cca'],  ax=ax2)
ax1.legend(loc = 'upper right', title='cluster')
plt.suptitle('To what extent do you agree or disagree with the following statement: \n We should reduce greenhouse gas emissions to a minimum while offsetting the remaining emissions, \n for instance by increasing forested areas, to make the EU economy climate neutral by 2050.')
plt.savefig('qb9-count-cc.png')

plt.show()

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-83-00cf07b74dcd> in <module>
# ----> 1 df
#
# NameError: name 'df' is not defined
