# %%
# Import Data 
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

df = pd.read_csv('df-climatechange.csv')
df = df.drop(['qb1a', 'Unnamed: 0'], axis = 1)
df['qb5'] = df['qb5'].replace({'No': 0, 'Yes':1})

df1 = df[df.qb2 >= 6]
df2 = df[df.qb2 <= 5]
#pd.set_option('display.max_columns', None)
df.head()
# Out:
#    Unnamed: 0.1  qb2  qb5  qb4_3  qb4_5  qb7  qb8  qb9           d1  d10  d11  \
# 0             0    4    0      2      2    2    2    2  Centre-left  Man   20
# 1             1    5    0      2      2    2    2    2  Centre-left  Man   55
# 2             2    6    0      2      2    2    1    1  Centre-left  Man   80
# 3             3    6    1      2      2    2    2    2       Centre  Man   40
# 4             4    5    1      3      3    2    3    2       Centre  Man   55
#
#           d25              d8                                d63  \
# 0  Large town  Still studying        The middle class of society
# 1  Large town      Refusal/dk        The middle class of society
# 2  Large town      Refusal/dk  The lower middle class of society
# 3  Large town      Refusal/dk  The lower middle class of society
# 4  Large town      Refusal/dk        The middle class of society
#
#                      d7  country  cca  cluster
# 0                Single  Belgium    1        1
# 1  Partner and children  Belgium    1        1
# 2                Single  Belgium    2        1
# 3  Partner and children  Belgium    1        1
# 4  Partner and children  Belgium    2        1

# %%
pd.set_option('display.max_rows', None)

pd.crosstab(df['d11'], df['qb5']).apply(lambda r: r/r.sum(), axis=1).plot()


#pd.crosstab(df['d11'], df['qb5'], margins=True)

# %%
pd.crosstab(df['qb2'], df['qb5']).apply(lambda r: r/r.sum(), axis=1).plot()
plt.title('Proportion of pro-environmental behaviour \n per climate change risk perception')
plt.xlabel('climate change risk perception')
plt.ylabel('Proportion of Pro-environmental behaviour')
plt.legend(["No Action", "Yes Action"]);
plt.savefig('qb5xqb2_prop.png')

# %%
pd.crosstab(df['qb2'], df['qb5']).apply(lambda r: r/r.sum(), axis=1)
# Out:
# qb5         0         1
# qb2
# 1    0.613636  0.386364
# 2    0.535032  0.464968
# 3    0.583106  0.416894
# 4    0.550756  0.449244
# 5    0.514804  0.485196
# 6    0.476960  0.523040
# 7    0.404777  0.595223
# 8    0.343135  0.656865
# 9    0.277572  0.722428
# 10   0.242792  0.757208

# %%
ct = pd.crosstab(df['cluster'], df['qb5']).apply(lambda r: r/r.sum(), axis=1)
ct.plot.bar(stacked=True)

# %%
ct
# Out:
# qb5             0         1
# cluster
# 1        0.443022  0.556978
# 2        0.250023  0.749977

# %%
ct = pd.crosstab(df['d25'], df['qb5']).apply(lambda r: r/r.sum(), axis=1)
ct.plot.bar(stacked=True)

# %%
ct = pd.crosstab(df['country'], df['qb5']).apply(lambda r: r/r.sum(), axis=1)
ct.plot.bar(stacked=True)

# %%
ct
# Out:
# qb5                    0         1
# country
# Austria         0.293976  0.706024
# Belgium         0.364948  0.635052
# Bulgaria        0.560703  0.439297
# Croatia         0.443584  0.556416
# Cyprus          0.350365  0.649635
# Czech Republic  0.551440  0.448560
# Denmark         0.226460  0.773540
# Estonia         0.469231  0.530769
# Finland         0.177200  0.822800
# France          0.317440  0.682560
# Germany         0.268333  0.731667
# Greece          0.406323  0.593677
# Hungary         0.316667  0.683333
# Ireland         0.331897  0.668103
# Italy           0.438674  0.561326
# Latvia          0.538574  0.461426
# Lithuania       0.437500  0.562500
# Luxembourg      0.180451  0.819549
# Malta           0.093199  0.906801
# Netherlands     0.328426  0.671574
# Poland          0.528169  0.471831
# Portugal        0.201622  0.798378
# Romania         0.666283  0.333717
# Slovakia        0.290123  0.709877
# Slovenia        0.177346  0.822654
# Spain           0.168293  0.831707
# Sweden          0.204494  0.795506
# United Kingdom  0.411972  0.588028

# %%
ct = pd.crosstab(df['d8'], df['qb5']).apply(lambda r: r/r.sum(), axis=1)
ct.plot.bar(stacked=True)

# %%
ct

# %%
ct
# Out:
# qb5                        0         1
# d8
# 16-19 years old     0.393353  0.606647
# 20+ years old       0.282478  0.717522
# Refusal/dk          0.457680  0.542320
# Still studying      0.371530  0.628470
# Up to 15 years old  0.368745  0.631255

# %%
ct = pd.crosstab(df['d63'], df['qb5']).apply(lambda r: r/r.sum(), axis=1)
ct.plot.bar(stacked=True)

# %%
pd.crosstab(df1['d11'], df1['qb5']).apply(lambda r: r/r.sum(), axis=1).plot()
plt.title('Proportion of pro-environmental behaviour per age class')
plt.xlabel('age')
plt.ylabel('Proportion of Pro-environmental behaviour')
plt.legend(["No Action", "Yes Action"]);
plt.savefig('qb5xqb2_prop.png')

# %%
pd.crosstab(df1['d11'], df1['qb5'])
# Out:
# qb5    0    1
# d11
# 15    18   43
# 16    36   74
# 17    59   77
# 18    73  147
# 19    76  134
# 20    78  103
# 21    57  118
# 22    68  130
# 23    74  145
# 24    69  133
# 25    76  139
# 26    68  144
# 27    76  152
# 28    93  171
# 29    92  184
# 30   106  179
# 31    78  158
# 32   110  208
# 33    94  204
# 34    76  188
# 35   110  224
# 36   109  197
# 37   101  196
# 38    70  226
# 39   118  232
# 40    95  216
# 41   105  216
# 42    97  220
# 43    82  212
# 44    79  198
# 45   116  233
# 46    90  179
# 47   103  189
# 48   116  261
# 49    81  222
# 50    99  246
# 51    88  197
# 52   106  283
# 53    89  203
# 54    87  245
# 55   127  258
# 56   107  245
# 57    98  211
# 58   108  250
# 59   113  245
# 60   123  254
# 61   100  218
# 62   121  281
# 63   108  238
# 64   106  231
# 65   143  290
# 66    91  243
# 67    92  270
# 68   114  248
# 69    95  228
# 70   128  231
# 71    99  191
# 72    95  217
# 73    79  186
# 74    63  170
# 75    79  175
# 76    48  121
# 77    52   95
# 78    63  105
# 79    40  112
# 80    38   91
# 81    37   63
# 82    38   65
# 83    47   52
# 84    27   50
# 85    22   27
# 86    19   26
# 87    14   26
# 88    12   11
# 89     6   12
# 90     4   11
# 91     2    6
# 92     5    3
# 93     1    2
# 94     0    3
# 95     1    0
# 98     1    1

# %%
pd.crosstab(df2['d11'], df2['qb5']).apply(lambda r: r/r.sum(), axis=1).plot()
plt.title('Proportion of pro-environmental behaviour per Age')
plt.xlabel('age')
plt.ylabel('Proportion of Pro-environmental behaviour')
plt.legend(["No Action", "Yes Action"]);

# %%
pd.crosstab(df2['d11'], df2['qb5'], margins=True)
# Out:
# qb5     0     1   All
# d11
# 15      6     2     8
# 16     14     5    19
# 17     17     4    21
# 18     21    12    33
# 19     26     8    34
# ..    ...   ...   ...
# 90      2     1     3
# 92      1     0     1
# 94      1     1     2
# 95      1     1     2
# All  1567  1339  2906
#
# [80 rows x 3 columns]

# %%
pd.crosstab(df1['cluster'], df1['qb5']).apply(lambda r: r/r.sum(), axis=1)
# Out:
# qb5             0         1
# cluster
# 1        0.407593  0.592407
# 2        0.240139  0.759861

# %%
pd.crosstab(df1['d8'], df1['qb5']).apply(lambda r: r/r.sum(), axis=1)
# Out:
# qb5                        0         1
# d8
# 16-19 years old     0.363796  0.636204
# 20+ years old       0.257818  0.742182
# Refusal/dk          0.390438  0.609562
# Still studying      0.335749  0.664251
# Up to 15 years old  0.341711  0.658289

# %%
pd.crosstab(df2['cluster'], df2['qb5']).apply(lambda r: r/r.sum(), axis=1)
# Out:
# qb5             0         1
# cluster
# 1        0.588397  0.411603
# 2        0.389121  0.610879

# %%
ct = pd.crosstab(df2['country'], df2['qb5']).apply(lambda r: r/r.sum(), axis=1)
ct.plot.bar(stacked=True)

# %%
ct
# Out:
# qb5                    0         1
# country
# Austria         0.237288  0.762712
# Belgium         0.333333  0.666667
# Bulgaria        0.550000  0.450000
# Croatia         0.408602  0.591398
# Cyprus          0.351206  0.648794
# Czech Republic  0.501712  0.498288
# Denmark         0.211096  0.788904
# Estonia         0.422164  0.577836
# Finland         0.150746  0.849254
# France          0.276056  0.723944
# Germany         0.241643  0.758357
# Greece          0.395377  0.604623
# Hungary         0.289855  0.710145
# Ireland         0.309927  0.690073
# Italy           0.417569  0.582431
# Latvia          0.483431  0.516569
# Lithuania       0.411559  0.588441
# Luxembourg      0.154930  0.845070
# Malta           0.092308  0.907692
# Netherlands     0.290587  0.709413
# Poland          0.520194  0.479806
# Portugal        0.198773  0.801227
# Romania         0.628134  0.371866
# Slovakia        0.274510  0.725490
# Slovenia        0.160995  0.839005
# Spain           0.165605  0.834395
# Sweden          0.177150  0.822850
# United Kingdom  0.373259  0.626741

# %%
ct = pd.crosstab(df2['country'], df2['qb5']).apply(lambda r: r/r.sum(), axis=1)
ct.plot.bar(stacked=True)

# %%
ct
# Out:
# qb5                    0         1
# country
# Austria         0.497238  0.502762
# Belgium         0.532468  0.467532
# Bulgaria        0.695652  0.304348
# Croatia         0.606250  0.393750
# Cyprus          0.342105  0.657895
# Czech Republic  0.751724  0.248276
# Denmark         0.340000  0.660000
# Estonia         0.595745  0.404255
# Finland         0.306569  0.693431
# France          0.655172  0.344828
# Germany         0.450980  0.549020
# Greece          0.687500  0.312500
# Hungary         0.625000  0.375000
# Ireland         0.509804  0.490196
# Italy           0.675676  0.324324
# Latvia          0.701149  0.298851
# Lithuania       0.548872  0.451128
# Luxembourg      0.386364  0.613636
# Malta           0.142857  0.857143
# Netherlands     0.513333  0.486667
# Poland          0.582418  0.417582
# Portugal        0.250000  0.750000
# Romania         0.847682  0.152318
# Slovakia        0.406250  0.593750
# Slovenia        0.290909  0.709091
# Spain           0.228571  0.771429
# Sweden          0.396396  0.603604
# United Kingdom  0.619403  0.380597

# %%
pd.crosstab(df['d1'], df['qb5']).apply(lambda r: r/r.sum(), axis=1)
pd.crosstab(df['d1'], df['qb5'])
# Out:
# qb5                  0     1
# d1
# Centre            2121  3801
# Centre-letf       1834  4068
# Centre-right      1364  2106
# Left               571  1282
# Not positionable  1123  2105
# Right              638   965

# %%
pd.crosstab(df2['d1'], df2['qb5']).apply(lambda r: r/r.sum(), axis=1)
#pd.crosstab(df2['d1'], df2['qb5'])
# Out:
# qb5                      0         1
# d1
# Centre            0.540601  0.459399
# Centre-letf       0.547688  0.452312
# Centre-right      0.546185  0.453815
# Left              0.533898  0.466102
# Not positionable  0.531856  0.468144
# Right             0.509091  0.490909

# %%
ct = pd.crosstab(df1['d8'], df1['qb5']).apply(lambda r: r/r.sum(), axis=1)
ct.plot.bar(stacked=True)

# %%
ct = pd.crosstab(df1['d25'], df1['qb5']).apply(lambda r: r/r.sum(), axis=1)
ct.plot.bar(stacked=True)

# %%
pd.crosstab(df1['d7'], df1['qb5']).apply(lambda r: r/r.sum(), axis=1)
# Out:
# qb5                          0         1
# d7
# Partner               0.320555  0.679445
# Partner and children  0.295938  0.704062
# Refusal/Other         0.444444  0.555556
# Single                0.342651  0.657349
# Single with children  0.320579  0.679421

# %%
pd.crosstab(df1['d25'], df1['qb5'])
# Out:
# qb5                            0     1
# d25
# Large town                  1764  3808
# Rural area or village       1921  4154
# Small or middle sized town  2398  5024
# dk                             1     2

# %%
df['country'].value_counts(normalize=True) * 100
# Out:
# Germany           5.460005
# Belgium           4.413504
# Ireland           4.222404
# Italy             4.117754
# Croatia           4.113204
# Hungary           4.095004
# Sweden            4.049504
# Netherlands       4.017654
# Slovenia          3.976704
# Romania           3.953954
# Portugal          3.926654
# Greece            3.885704
# United Kingdom    3.876604
# Denmark           3.817454
# Austria           3.776504
# Spain             3.731004
# Slovakia          3.685504
# Finland           3.671854
# France            3.626354
# Czech Republic    3.316953
# Poland            3.230503
# Lithuania         3.203203
# Latvia            3.125853
# Bulgaria          2.848303
# Estonia           2.366002
# Cyprus            1.870052
# Luxembourg        1.815452
# Malta             1.806352
# Name: country, dtype: float64

# %%
df.qb2.mean()
# Out:
# 7.939257439257439

# %%
df.groupby('cca').count()
# Out:
#      Unnamed: 0.1   qb2   qb5  qb4_3  qb4_5   qb7   qb8   qb9    d1   d10  \
# cca
# 1            5704  5704  5704   5704   5704  5704  5704  5704  5704  5704
# 2            4415  4415  4415   4415   4415  4415  4415  4415  4415  4415
# 3            6106  6106  6106   6106   6106  6106  6106  6106  6106  6106
# 4            3271  3271  3271   3271   3271  3271  3271  3271  3271  3271
# 5            2482  2482  2482   2482   2482  2482  2482  2482  2482  2482
#
#       d11   d25    d8   d63    d7  country  cluster
# cca
# 1    5704  5704  5704  5704  5704     5704     5704
# 2    4415  4415  4415  4415  4415     4415     4415
# 3    6106  6106  6106  6106  6106     6106     6106
# 4    3271  3271  3271  3271  3271     3271     3271
# 5    2482  2482  2482  2482  2482     2482     2482

# %%
P = df.groupby('Risk Percepetion Level')['qb2'].count().reset_index()
P['perc'] = 100 * P['qb2']  / P['qb2'].sum()

P
# Out:
#    cluster    qb2       perc
# 0        1  11171  50.828101
# 1        2  10807  49.171899

# %%
df.groupby(['cca', 'd1']).count()
# Out:
#                       Unnamed: 0.1   qb2   qb5  qb4_3  qb4_5   qb7   qb8  \
# cca d1
# 1   Centre                    1559  1559  1559   1559   1559  1559  1559
#     Centre-left               1381  1381  1381   1381   1381  1381  1381
#     Centre-right               762   762   762    762    762   762   762
#     Left                       510   510   510    510    510   510   510
#     Not positionable          1053  1053  1053   1053   1053  1053  1053
#     Right                      439   439   439    439    439   439   439
# 2   Centre                    1209  1209  1209   1209   1209  1209  1209
#     Centre-left               1255  1255  1255   1255   1255  1255  1255
#     Centre-right               770   770   770    770    770   770   770
#     Left                       332   332   332    332    332   332   332
#     Not positionable           531   531   531    531    531   531   531
#     Right                      318   318   318    318    318   318   318
# 3   Centre                    1576  1576  1576   1576   1576  1576  1576
#     Centre-left               1740  1740  1740   1740   1740  1740  1740
#     Centre-right              1037  1037  1037   1037   1037  1037  1037
#     Left                       499   499   499    499    499   499   499
#     Not positionable           835   835   835    835    835   835   835
#     Right                      419   419   419    419    419   419   419
# 4   Centre                     923   923   923    923    923   923   923
#     Centre-left                817   817   817    817    817   817   817
#     Centre-right               487   487   487    487    487   487   487
#     Left                       289   289   289    289    289   289   289
#     Not positionable           512   512   512    512    512   512   512
#     Right                      243   243   243    243    243   243   243
# 5   Centre                     655   655   655    655    655   655   655
#     Centre-left                709   709   709    709    709   709   709
#     Centre-right               414   414   414    414    414   414   414
#     Left                       223   223   223    223    223   223   223
#     Not positionable           297   297   297    297    297   297   297
#     Right                      184   184   184    184    184   184   184
#
#                        qb9   d10   d11   d25    d8   d63    d7  country  \
# cca d1
# 1   Centre            1559  1559  1559  1559  1559  1559  1559     1559
#     Centre-left       1381  1381  1381  1381  1381  1381  1381     1381
#     Centre-right       762   762   762   762   762   762   762      762
#     Left               510   510   510   510   510   510   510      510
#     Not positionable  1053  1053  1053  1053  1053  1053  1053     1053
#     Right              439   439   439   439   439   439   439      439
# 2   Centre            1209  1209  1209  1209  1209  1209  1209     1209
#     Centre-left       1255  1255  1255  1255  1255  1255  1255     1255
#     Centre-right       770   770   770   770   770   770   770      770
#     Left               332   332   332   332   332   332   332      332
#     Not positionable   531   531   531   531   531   531   531      531
#     Right              318   318   318   318   318   318   318      318
# 3   Centre            1576  1576  1576  1576  1576  1576  1576     1576
#     Centre-left       1740  1740  1740  1740  1740  1740  1740     1740
#     Centre-right      1037  1037  1037  1037  1037  1037  1037     1037
#     Left               499   499   499   499   499   499   499      499
#     Not positionable   835   835   835   835   835   835   835      835
#     Right              419   419   419   419   419   419   419      419
# 4   Centre             923   923   923   923   923   923   923      923
#     Centre-left        817   817   817   817   817   817   817      817
#     Centre-right       487   487   487   487   487   487   487      487
#     Left               289   289   289   289   289   289   289      289
#     Not positionable   512   512   512   512   512   512   512      512
#     Right              243   243   243   243   243   243   243      243
# 5   Centre             655   655   655   655   655   655   655      655
#     Centre-left        709   709   709   709   709   709   709      709
#     Centre-right       414   414   414   414   414   414   414      414
#     Left               223   223   223   223   223   223   223      223
#     Not positionable   297   297   297   297   297   297   297      297
#     Right              184   184   184   184   184   184   184      184
#
#                       cluster
# cca d1
# 1   Centre               1559
#     Centre-left          1381
#     Centre-right          762
#     Left                  510
#     Not positionable     1053
#     Right                 439
# 2   Centre               1209
#     Centre-left          1255
#     Centre-right          770
#     Left                  332
#     Not positionable      531
#     Right                 318
# 3   Centre               1576
#     Centre-left          1740
#     Centre-right         1037
#     Left                  499
#     Not positionable      835
#     Right                 419
# 4   Centre                923
#     Centre-left           817
#     Centre-right          487
#     Left                  289
#     Not positionable      512
#     Right                 243
# 5   Centre                655
#     Centre-left           709
#     Centre-right          414
#     Left                  223
#     Not positionable      297
#     Right                 184
